# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup as bsp

# %%
url = 'https://www.imdb.com/title/tt0903747/reviews?ref_=tt_urv'

response = requests.get(url)
soup = bsp(response.content, "html.parser")

# %%
movies = []
for comment in soup.find_all("div", class_="lister-item-content"):
    titles = comment.find("a", class_="title").string.rstrip('\n').strip(' ')
    comments = comment.find_all("div", class_='text')
    for cmt in comments:
        movies.append({'title':titles, 'comment': cmt.text})

# %%
pd.DataFrame(movies)
# Out:
#                                                 title  \
# 0                                            The Best
# 1                                     It's ok I guess
# 2                                Dont watch this show
# 3                  Those days ain't gonna come back..
# 4                                            The best
# 5                             Best TV show ever made.
# 6   If you mix Scarface, Robin Hood and maybe Tyle...
# 7                                         Im in tears
# 8                                     The 10/10 show.
# 9   Since GOT is over, this is Officially the Grea...
# 10                            Addicted: Meth or Math.
# 11                                       Unbelievable
# 12                              Stunning Comedy-Drama
# 13                           Don't watch this show...
# 14                                          BABY BLUE
# 15           How can this be anything less than 10???
# 16           Breaking Bad is the best television show
# 17                                       Mind Blowing
# 18                                    Incredible Show
# 19                                   Beyond Brilliant
# 20                                         An apology
# 21                                      Mind blowing!
# 22                         Please stay on the air....
# 23  I just want to lose my memory so that i can re...
# 24    Breaking Bad is a Once In a Lifetime Experience
#
#                                               comment
# 0   I cannot stress enough how good this show is. ...
# 1   Re-Watched it 7 times and counting. I guess I ...
# 2   Dont you ever watch this show as it is so perf...
# 3   When you finish the show you'll never be the s...
# 4   The best series I have seen in my whole life, ...
# 5   I wanna delete my brain and watch it again lik...
# 6   If you are among the few who haven't seen it y...
# 7   Just finished watching for the second time and...
# 8   If there is any show deserves a 10/10, it's Br...
# 9   I was waiting to see how GOT ended. It should ...
# 10  Drug wars, meth, the lot. I thought no thank y...
# 11  This is by far the greatest TV show ever.I was...
# 12  I probably haven't been hooked to a TV show li...
# 13  ...unless you want to be hooked to it. It's li...
# 14  Okay many of you must have read all the review...
# 15  MY ALL TIME FAVORITE TV SHOW, PERIOD!IT'S GREA...
# 16  "Breaking Bad" is the best television show. Ev...
# 17  BREAKING BAD:Season One explodes like a sucker...
# 18  I have to echo another reviewer on here and sa...
# 19  Breaking Bad has been off the air for some yea...
# 20  Many years ago, a friend of mine told me to wa...
# 21  I cannot believe that I disregarded this serie...
# 22  Absolutely one of the most ground breaking bad...
# 23  Not a series it's like a lesson of someone to ...
# 24  After many friends recommending me the show i ...
