# %%
from splocked.utils import imdb_api, get_reviews, movie_info

# %%
imdb_api("House")
# Out:
# 'tt0412142'

# %%
get_reviews('tt0412142')
# Out:
#                                                 title  \
# 0                                     My kind of show
# 1                                          Great Show
# 2                  Interesting bordering on excellent
# 3             The most brilliant medical show to date
# 4                           You must watch this show!
# 5   Simply House is the best medical series made o...
# 6                   Finally, a network show I like. .
# 7                     A show worth looking forward to
# 8   One of the most intelligent programs in televi...
# 9                       Fine "medical detective" show
# 10                                        Hugh Laurie
# 11                               Riot in the "House"!
# 12                       Best hospital show since ER!
# 13                                        It's Lupus!
# 14                           Laurie's accent is fine.
# 15               One of the best shows I've EVER seen
# ...

# %%
movie_info('tt0412142')
# Out:
# ('House M.D.',
#  'An antisocial maverick doctor who specializes in diagnostic medicine does whatever it takes to solve puzzling cases that come his way using his crack team of doctors and his wits.',
#  'https://m.media-amazon.com/images/M/MV5BMDA4NjQzN2ItZDhhNC00ZjVlLWFjNTgtMTEyNDQyOGNjMDE1XkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_UY268_CR0,0,182,268_AL_.jpg')
